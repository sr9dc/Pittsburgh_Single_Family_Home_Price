# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# CD to project code directory
import os
os.chdir('/content/drive/MyDrive/Group_Project/Project_Code')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from geopy import distance
import math
import plotly.express as px

pd.set_option('display.max_columns', 3000)
pd.set_option('display.max_rows', 3000)

# %%
homes = pd.read_pickle('Redfin_pickle_new')

# %%
# Create a copy to play with
redfin_cr = homes.copy()
# Normalize Crime Score between 0-100
#redfin_cr['Crime Score'] = ((redfin_cr['Crime Score'] - redfin_cr['Crime Score'].min()) / (redfin_cr['Crime Score'].max() - redfin_cr['Crime Score'].min()))*100

# %%
display(redfin_cr.head())
# Out:
#        PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 2   275000.0   4.0    4.0       1785.0    1306.0      1900.0
# 3   302500.0   5.0    2.0       3034.0    2178.0      1900.0
# 4   301000.0   3.0    1.5       1972.0    1306.0      1890.0
# 9   379900.0   2.0    1.5       1226.0    1742.0      1890.0
# 11  390000.0   3.0    3.0       1519.0    2178.0      1910.0
#
#    URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 2   https://www.redfin.com/PA/Pittsburgh/45-Greele...
# 3   https://www.redfin.com/PA/Pittsburgh/259-45th-...
# 4   https://www.redfin.com/PA/Pittsburgh/431-Taylo...
# 9   https://www.redfin.com/PA/Pittsburgh/159-1-2-3...
# 11  https://www.redfin.com/PA/Pittsburgh/4919-Hatf...
#
#      Neighborhood                   Location         dt  Crime Score
# 2      South Side  (-79.9743145, 40.4229551) 2021-10-01    35.380360
# 3   Lawrenceville  (-79.9576202, 40.4711406) 2021-06-01    25.490296
# 4      Bloomfield  (-79.9523315, 40.4605557) 2021-10-01    26.678413
# 9   Lawrenceville  (-79.9655419, 40.4679636) 2021-09-01    17.730598
# 11  Lawrenceville  (-79.9573142, 40.4780842) 2020-12-01    15.909914

# %%
fig = px.scatter_geo(data_frame = redfin_cr, lat = redfin_cr.Location.str[1], lon = redfin_cr.Location.str[0], color = "Crime Score",
                    scope = 'usa', fitbounds = "locations")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="55e1beff-a09d-4a38-911f-932d23fb3835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55e1beff-a09d-4a38-911f-932d23fb3835")) {                    Plotly.newPlot(                        "55e1beff-a09d-4a38-911f-932d23fb3835",                        [{"geo":"geo","hovertemplate":"lat=%{lat}<br>lon=%{lon}<br>Crime Score=%{marker.color}<extra></extra>","lat":[40.4229551,40.4711406,40.4605557,40.4679636,40.4780842,40.4619007,40.4264991,40.4205813,40.4614483,40.4278209,40.4723218,40.4406758,40.4696381,40.417499,40.419905,40.4237429,40.4331466,40.465461,40.4505539,40.42968,40.4791237,40.4834182,40.4711589,40.4356812,40.4405513,40.478046,40.4261257,40.4448738,40.470133,40.4203293,40.465276,40.4418696,40.455656,40.456912,40.478297,40.4259884,40.4832445,40.4059452,40.4193459,40.423067,40.4776714,40.4638814,40.4316591,40.4178585,40.4832973,40.4343792,40.421358,40.452126,40.4539561,40.4848132,40.4866158,40.4268427,40.4787428,40.4786603,40.4264845,40.470308,40.4201811,40.4698315,40.4230412,40.4548382,40.4802854,40.4448168,40