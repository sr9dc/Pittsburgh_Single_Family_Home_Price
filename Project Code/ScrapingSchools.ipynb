# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# CD to project code directory
import os
os.chdir('/content/drive/MyDrive/Group_Project/Project_Code')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from geopy import distance
import math
import plotly.express as px

pd.set_option('display.max_columns', 3000)
pd.set_option('display.max_rows', 3000)

# %%
homes = pd.read_pickle('Redfin_pickle')

# %%
# Create a copy to play with
redfin_cr = homes.copy()
# Normalize Crime Score between 0-100
redfin_cr['Crime Score'] = ((redfin_cr['Crime Score'] - redfin_cr['Crime Score'].min()) / (redfin_cr['Crime Score'].max() - redfin_cr['Crime Score'].min()))*100

# %%
display(redfin_cr.head())
# Out:
#        PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 6   379900.0   2.0    1.5       1226.0    1742.0      1890.0
# 8   390000.0   3.0    3.0       1519.0    2178.0      1910.0
# 14  302500.0   5.0    2.0       3034.0    2178.0      1900.0
# 16  301000.0   3.0    1.5       1972.0    1306.0      1890.0
# 24  396000.0   3.0    2.0       1462.0    4081.0      1926.0
#
#    URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 6   https://www.redfin.com/PA/Pittsburgh/159-1-2-3...
# 8   https://www.redfin.com/PA/Pittsburgh/4919-Hatf...
# 14  https://www.redfin.com/PA/Pittsburgh/259-45th-...
# 16  https://www.redfin.com/PA/Pittsburgh/431-Taylo...
# 24  https://www.redfin.com/PA/Pittsburgh/6529-Stan...
#
#      Neighborhood                   Location         dt  Crime Score
# 6   Lawrenceville  (-79.9655419, 40.4679636) 2021-09-01    19.323894
# 8   Lawrenceville  (-79.9573142, 40.4780842) 2020-12-01    17.338284
# 14  Lawrenceville  (-79.9576202, 40.4711406) 2021-06-01    27.786509
# 16     Bloomfield  (-79.9523315, 40.4605557) 2021-10-01    29.082252
# 24  Highland Park  (-79.9115632, 40.4723218) 2022-08-01     7.276906

# %%
redfin_cr.iloc[0, 6]
# Out:
# 'https://www.redfin.com/PA/Pittsburgh/159-1-2-38th-St-15201/home/74651930'

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup

url = 'https://www.publicschoolreview.com/pennsylvania/pittsburgh'
req = Request(url, headers={'User-Agent' : 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %%
print(webpage)
# Out:
# b'<!DOCTYPE html><html\nlang="en" id="top-of-site"><head><link\nrel="dns-prefetch" href="https://www.googletagmanager.com/" ><link\nrel="dns-prefetch" href="https://static.publicschoolreview.com/" ><link\nrel="dns-prefetch" href="https://images1.publicschoolreview.com/" ><link\nrel="dns-prefetch" href="https://images2.publicschoolreview.com/" ><link\nrel="dns-prefetch" href="https://images3.publicschoolreview.com/" >\n <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n        new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n        j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n        \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-KVXLX\');</script> <title>Top 10 Best Pittsburgh, PA Public Schools (2022-23)</title><meta\nhttp-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta\nname="format-detection" content="telephone=no"/><meta\ncharset="utf-8"/><meta\nname="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=yes"><meta\nname="description" content="View the top 10 best public schools in Pittsburgh, Pennsylvania 2022-23. Find rankings, test scores, reviews and more. Read about great schools like: Fairview Elementary School, Upper Saint Clair High School and Markham Elementary School." /><link\nrel="preload" href="//static.publicschoolreview.com/static/montserrat.1174354964.woff" as="font" type="font/woff" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/montserrat_medium.96219297.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_300_first.2206587387.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_300_second.2006473154.woff" as="font" type="font/woff" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_400_first.1322156528.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_400_second.4110187076.woff" as="font" type="font/woff" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_500_first.1036965829.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_500_second.3289978379.woff" as="font" type="font/woff" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_600_first.1063676667.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_600_second.2643287833.woff" as="font" type="font/woff" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_700_first.2432116651.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/hind_700_second.1110057839.woff" as="font" type="font/woff" crossorigin="anonymous"><link\nrel="preload" href="//static.publicschoolreview.com/static/fcicons.1426725419.ttf" as="font" type="font/ttf" crossorigin="anonymous"><link\nrel="canonical" href="https://www.publicschoolreview.com/pennsylvania/pittsburgh"><link\nrel="dns-prefetch" href="https://a.tile.openstreetmap.org"><link\nrel="dns-prefetch" href="https://b.tile.openstreetmap.org"><link\nrel="dns-prefetch" href="https://c.tile.openstreetmap.org"><link\nrel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png?v=yyxmRQnxXd"><link\nrel="icon" type="image/png" href="/favicon-32x32.png?v=yyxmRQnxXd" sizes="32x32"><link\nrel="icon" type="image/png" href="/favicon-16x16.png?v=yyxmRQnxXd" sizes="16x16"><link\nrel="manifest" href="/manifest.json?v=yyxmRQnxXd"><link\nrel="mask-icon" ...
